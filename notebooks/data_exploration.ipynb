# %%
import pandas as pd
import path
df = pd.read_csv(path.Path('../data/cab_rides_with_weather.csv'))
df.head()
# Out:
#    distance cab_type       destination                   source  price  \
# 0      3.03     Lyft  Theatre District        Boston University   34.0
# 1      1.30     Uber  Theatre District            South Station   18.5
# 2      2.43     Lyft       Beacon Hill  Northeastern University   10.5
# 3      2.71     Uber            Fenway         Theatre District   32.0
# 4      2.71     Uber            Fenway         Theatre District   19.5
#
#    surge_multiplier          name                ride_time   temp  clouds  \
# 0               1.0  Lux Black XL  2018-11-26 03:40:46.318  41.07    0.86
# 1               1.0         Black  2018-11-26 03:40:46.319  40.86    0.87
# 2               1.0          Lyft  2018-11-26 03:40:46.320  40.81    0.89
# 3               1.0        UberXL  2018-11-26 03:40:46.320  40.80    0.87
# 4               1.0         UberX  2018-11-26 03:40:46.320  40.80    0.87
#
#    pressure  rain  humidity  wind         weather_time  time_gap_minutes
# ...

# %%
df.columns
# Out:
# Index(['distance', 'cab_type', 'destination', 'source', 'price',
#        'surge_multiplier', 'name', 'ride_time', 'temp', 'clouds', 'pressure',
#        'rain', 'humidity', 'wind', 'weather_time', 'time_gap_minutes'],
#       dtype='str')
